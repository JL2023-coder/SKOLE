# %% [markdown]
# # Modeling
# ___

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import root_mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.dummy import DummyRegressor
from sklearn import clone
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import numpy as np
import time

# %% [markdown]
# Importing data

# %%
X_train = pd.read_csv('../cleaned_data/X_train.csv')
y_train = pd.read_csv('../cleaned_data/y_train.csv')

X_test = pd.read_csv('../cleaned_data/X_test.csv')
y_test = pd.read_csv('../cleaned_data/y_test.csv')

X_val = pd.read_csv('../cleaned_data/X_val.csv')
y_val = pd.read_csv('../cleaned_data/y_val.csv')

# %% [markdown]
# Below I encountered a problem where y wasnt a 1d array, which it should be for the machine learn training, I will therefore use ravel to chenge the array from 2d to 1d.

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)

y_train = y_train.values.ravel()
y_test = y_test.values.ravel()
y_val = y_val.values.ravel()

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
# Out:
# X_train shape: (4637, 60)
# y_train shape: (4637, 1)
# X_test shape: (1546, 60)
# y_test shape: (1546, 1)
# X_val shape: (1546, 60)
# y_val shape: (1546, 1)
# X_train shape: (4637, 60)
# y_train shape: (4637,)
# X_test shape: (1546, 60)
# y_test shape: (1546,)
# X_val shape: (1546, 60)
# y_val shape: (1546,)

# %% [markdown]
# #### What needs to be imputed
# ___

# %% [markdown]
# First we will check what we need to impute

# %%
nan_counts = X_train.isnull().sum()
nan_percentage = (nan_counts / len(X_train)) * 100
nan_summary = pd.DataFrame({
    'NaN Count': nan_counts,
    'Percentage': nan_percentage
})

nan_summary = nan_summary[nan_summary['NaN Count'] > 0]

print(nan_summary)
# Out:
#                                NaN Count  Percentage
# utdanning                            845   18.222989
# hvite_blodlegemer                    112    2.415355
# lungefunksjon                       1204   25.965064
# serumalbumin                        1725   37.200776
# bilirubin                           1321   28.488247
# kreatinin                             32    0.690101
# blod_ph                             1182   25.490619
# glukose                             2304   49.687298
# blodurea_nitrogen                   2219   47.854216
# urinmengde                          2476   53.396593
# adl_pasient                         2885   62.216951
# adl_stedfortreder                   1462   31.529006
# lege_overlevelsesestimat_2mnd        840   18.115161
# lege_overlevelsesestimat_6mnd        832   17.942635
# dnr_dag                             4002   86.305801

# %% [markdown]
# #### Baseline model
# ___

# %% [markdown]
# We will use use a baseline model to compare the RMSE values, for this I will use a DummyRegressor, I will try two differnt impuation techniques, median and mean.

# %%
mean_imputer = SimpleImputer(strategy='mean')
median_imputer = SimpleImputer(strategy='median')

mean_pipeline = Pipeline(steps=[('imputer', mean_imputer), ('scaler', StandardScaler()), ('regressor', DummyRegressor())])
mean_pipeline.fit(X_train, y_train)
y_pred_mean = mean_pipeline.predict(X_val)
baseline_rmse_mean = (root_mean_squared_error(y_val, y_pred_mean))
print(f"Baseline RMSE (Mean Imputer): {baseline_rmse_mean:.2f}")

median_pipeline = Pipeline(steps=[('imputer', median_imputer), ('scaler', StandardScaler()), ('regressor', DummyRegressor())])
median_pipeline.fit(X_train, y_train)
y_pred_median = median_pipeline.predict(X_val)
baseline_rmse_median = (root_mean_squared_error(y_val, y_pred_median))
print(f"Baseline RMSE (Median Imputer): {baseline_rmse_median:.2f}")
# Out:
# Baseline RMSE (Mean Imputer): 20.83
# Baseline RMSE (Median Imputer): 20.83

# %% [markdown]
# #### Imputers and Machine Learning Models
# ___

# %%
imputers = {
    'mean': SimpleImputer(strategy='mean'),
    'median': SimpleImputer(strategy='median'),
    'mode': SimpleImputer(strategy='most_frequent'),
    'knn5': KNNImputer(n_neighbors=5),
    'knn10': KNNImputer(n_neighbors=10)
}

models = {
    'Linear': LinearRegression(),
    'ElasticNet0.5': ElasticNet(alpha=0.5),
    'ElasticNet1': ElasticNet(alpha=1),
    'KNN5': KNeighborsRegressor(n_neighbors=5),
    'KNN10': KNeighborsRegressor(n_neighbors=10),
    'FullRandForest': RandomForestRegressor(),
    'SmallRandForest': RandomForestRegressor(n_estimators=50, max_depth=10),
    'SVR_poly_C1': SVR(kernel='poly', degree=2, C=1),
    'SVR_poly_C10': SVR(kernel='poly', degree=2, C=10),
    'SVR_rbf_C1': SVR(kernel='rbf', C=1, gamma='scale'),
    'SVR_rbf_C10': SVR(kernel='rbf', C=10, gamma='auto')
}

cont_features = ['blodtrykk', 'hvite_blodlegemer', 'hjertefrekvens', 'respirasjonsfrekvens', 'kroppstemperatur', 'lungefunksjon', 'serumalbumin', 'bilirubin', 'kreatinin', 'natrium', 'blod_ph', 'glukose', 'blodurea_nitrogen', 'urinmengde', 'koma_score', 'fysiologisk_score', 'apache_fysiologisk_score', 'overlevelsesestimat_2mnd', 'overlevelsesestimat_6mnd']
cat_features = [feat for feat in X_train.columns if feat not in cont_features]

# %% [markdown]
# #### Defining HyperParameters Tuning Space
# ___

# %%
param_grid = {
    'cont_imputer': list(imputers.keys()),
    'cat_imputer': list(imputers.keys()),
    'model': list(models.keys()),
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 5, 10, 20],
    'learning_rate': [0.01, 0.1, 1],
    'C': [0.1, 1, 10],
    'gamma': [0.001, 0.01, 0.1],
    'alpha': [0.1, 1, 10],
    'l1_ratio': [0.1, 0.5, 0.9] 
}

# %% [markdown]
# #### Pipeline
# ___

# %% [markdown]
# We will create a pipeline and objective function for the tuning of hyperParameters, we test each cont_imputation and cat_imputation method together with each meachine models to find the best combination.

# %%
results = []

def create_pipeline(cont_imputer, cat_imputer, model):
    preprocess = ColumnTransformer(transformers=[
        ('num', Pipeline(steps=[('impute', clone(cont_imputer)), ('scaler', StandardScaler())]), X_train.select_dtypes(include=['int64', 'float64']).columns),
        ('cat', Pipeline(steps=[('impute', clone(cat_imputer))]), X_train.select_dtypes(include=['object']).columns)
    ])
    
    pipeline = Pipeline([
        ('preprocess', preprocess),
        ('model', model)
    ])
    
    return pipeline

def objective(params):
    start_time = time.time()
    pipeline = create_pipeline(
        imputers[params['cont_imputer']],
        imputers[params['cat_imputer']],
        models[params['model']]
    )
    
    print(f"Running model: {params['model']} with imputers {params['cont_imputer']}, {params['cat_imputer']}")
    
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_val)
    rmse = (root_mean_squared_error(y_val, y_pred))
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Model completed in {elapsed_time:.2f} seconds. RMSE: {rmse}")

    results.append({'params': params, 'rmse': rmse})
    
    return rmse

for cont_imputer in param_grid['cont_imputer']:
    for cat_imputer in param_grid['cat_imputer']:
        for model in param_grid['model']:
            params = {
                'cont_imputer': cont_imputer,
                'cat_imputer': cat_imputer,
                'model': model
            }
            objective(params)

results.sort(key=lambda x: x['rmse'])

best_result = results[0]
best_cont_imputer = imputers[best_result['params']['cont_imputer']]
best_cat_imputer = imputers[best_result['params']['cat_imputer']]
best_model = models[best_result['params']['model']]

best_pipeline = create_pipeline(best_cont_imputer, best_cat_imputer, best_model)
best_pipeline.fit(X_train, y_train)
y_pred_test = best_pipeline.predict(X_test)
test_rmse = (root_mean_squared_error(y_test, y_pred_test))
print("Test RMSE:", test_rmse)
# Out:
# Running model: Linear with imputers mean, mean
# Model completed in 0.07 seconds. RMSE: 20.293455398177354
# Running model: Polynomial2 with imputers mean, mean
# Model completed in 0.02 seconds. RMSE: 20.293455398177354
# Running model: ElasticNet0.5 with imputers mean, mean
# Model completed in 0.02 seconds. RMSE: 20.24223606970142
# Running model: ElasticNet1 with imputers mean, mean
# Model completed in 0.02 seconds. RMSE: 20.332287576709536
# Running model: KNN5 with imputers mean, mean
# Model completed in 0.13 seconds. RMSE: 20.634906182715483
# Running model: KNN10 with imputers mean, mean
# Model completed in 0.03 seconds. RMSE: 19.98432697663162
# Running model: FullRandForest with imputers mean, mean
# Model completed in 6.23 seconds. RMSE: 19.059763924059492
# Running model: SmallRandForest with imputers mean, mean
# Model completed in 1.50 seconds. RMSE: 18.975986527127194
# Running model: SVR_poly_C1 with imputers mean, mean
# Model completed in 0.86 seconds. RMSE: 21.07376654840994
# Running model: SVR_poly_C10 with imputers mean, mean
# Model completed in 1.46 seconds. RMSE: 20.590860331451935
# Running model: SVR_rbf_C1 with imputers mean, mean
# Model completed in 1.39 seconds. RMSE: 20.399462383807773
# Running model: SVR_rbf_C10 with imputers mean, mean
# Model completed in 1.60 seconds. RMSE: 19.723914991262646
# Running model: Linear with imputers mean, median
# Model completed in 0.01 seconds. RMSE: 20.293455398177354
# Running model: Polynomial2 with imputers mean, median
# Model completed in 0.01 seconds. RMSE: 20.293455398177354
# Running model: ElasticNet0.5 with imputers mean, median
# Model completed in 0.02 seconds. RMSE: 20.24223606970142
# Running model: ElasticNet1 with imputers mean, median
# Model completed in 0.02 seconds. RMSE: 20.332287576709536
# Running model: KNN5 with imputers mean, median
# Model completed in 0.03 seconds. RMSE: 20.634906182715483
# Running model: KNN10 with imputers mean, median
# Model completed in 0.04 seconds. RMSE: 19.98432697663162
# Running model: FullRandForest with imputers mean, median
# Model completed in 6.23 seconds. RMSE: 19.371330887403904
# Running model: SmallRandForest with imputers mean, median
# Model completed in 1.47 seconds. RMSE: 18.924266360467474
# Running model: SVR_poly_C1 with imputers mean, median
# Model completed in 0.81 seconds. RMSE: 21.07376654840994
# Running model: SVR_poly_C10 with imputers mean, median
# Model completed in 1.34 seconds. RMSE: 20.590860331451935
# Running model: SVR_rbf_C1 with imputers mean, median
# Model completed in 1.35 seconds. RMSE: 20.399462383807773
# Running model: SVR_rbf_C10 with imputers mean, median
# Model completed in 1.60 seconds. RMSE: 19.723914991262646
# Running model: Linear with imputers mean, mode
# Model completed in 0.01 seconds. RMSE: 20.293455398177354
# Running model: Polynomial2 with imputers mean, mode
# Model completed in 0.02 seconds. RMSE: 20.293455398177354
# Running model: ElasticNet0.5 with imputers mean, mode
# Model completed in 0.02 seconds. RMSE: 20.24223606970142
# Running model: ElasticNet1 with imputers mean, mode
# Model completed in 0.02 seconds. RMSE: 20.332287576709536
# Running model: KNN5 with imputers mean, mode
# Model completed in 0.02 seconds. RMSE: 20.634906182715483
# Running model: KNN10 with imputers mean, mode
# Model completed in 0.03 seconds. RMSE: 19.98432697663162
# Running model: FullRandForest with imputers mean, mode
# Model completed in 6.23 seconds. RMSE: 19.2151054021176
# Running model: SmallRandForest with imputers mean, mode
# Model completed in 1.48 seconds. RMSE: 18.951453701016636
# Running model: SVR_poly_C1 with imputers mean, mode
# Model completed in 0.83 seconds. RMSE: 21.07376654840994
# Running model: SVR_poly_C10 with imputers mean, mode
# Model completed in 1.41 seconds. RMSE: 20.590860331451935
# Running model: SVR_rbf_C1 with imputers mean, mode
# Model completed in 1.37 seconds. RMSE: 20.399462383807773
# Running model: SVR_rbf_C10 with imputers mean, mode
# Model completed in 1.55 seconds. RMSE: 19.723914991262646
# Running model: Linear with imputers mean, knn5
# Model completed in 0.01 seconds. RMSE: 20.293455398177354
# Running model: Polynomial2 with imputers mean, knn5
# Model completed in 0.01 seconds. RMSE: 20.293455398177354
# Running model: ElasticNet0.5 with imputers mean, knn5
# Model completed in 0.01 seconds. RMSE: 20.24223606970142
# Running model: ElasticNet1 with imputers mean, knn5
# Model completed in 0.01 seconds. RMSE: 20.332287576709536
# Running model: KNN5 with imputers mean, knn5
# Model completed in 0.02 seconds. RMSE: 20.634906182715483
# Running model: KNN10 with imputers mean, knn5
# Model completed in 0.03 seconds. RMSE: 19.98432697663162
# Running model: FullRandForest with imputers mean, knn5
# Model completed in 6.16 seconds. RMSE: 19.288683076492177
# Running model: SmallRandForest with imputers mean, knn5
# Model completed in 1.47 seconds. RMSE: 19.003350812586834
# Running model: SVR_poly_C1 with imputers mean, knn5
# Model completed in 0.81 seconds. RMSE: 21.07376654840994
# Running model: SVR_poly_C10 with imputers mean, knn5
# Model completed in 1.36 seconds. RMSE: 20.590860331451935
# Running model: SVR_rbf_C1 with imputers mean, knn5
# Model completed in 1.39 seconds. RMSE: 20.399462383807773
# Running model: SVR_rbf_C10 with imputers mean, knn5
# Model completed in 1.60 seconds. RMSE: 19.723914991262646
# Running model: Linear with imputers mean, knn10
# Model completed in 0.01 seconds. RMSE: 20.293455398177354
# Running model: Polynomial2 with imputers mean, knn10
# Model completed in 0.01 seconds. RMSE: 20.293455398177354
# Running model: ElasticNet0.5 with imputers mean, knn10
# Model completed in 0.02 seconds. RMSE: 20.24223606970142
# Running model: ElasticNet1 with imputers mean, knn10
# Model completed in 0.01 seconds. RMSE: 20.332287576709536
# Running model: KNN5 with imputers mean, knn10
# Model completed in 0.02 seconds. RMSE: 20.634906182715483
# Running model: KNN10 with imputers mean, knn10
# Model completed in 0.03 seconds. RMSE: 19.98432697663162
# Running model: FullRandForest with imputers mean, knn10
# Model completed in 6.16 seconds. RMSE: 19.124668435178112
# Running model: SmallRandForest with imputers mean, knn10
# Model completed in 1.45 seconds. RMSE: 18.847125678362918
# Running model: SVR_poly_C1 with imputers mean, knn10
# Model completed in 0.80 seconds. RMSE: 21.07376654840994
# Running model: SVR_poly_C10 with imputers mean, knn10
# Model completed in 1.36 seconds. RMSE: 20.590860331451935
# Running model: SVR_rbf_C1 with imputers mean, knn10
# Model completed in 1.34 seconds. RMSE: 20.399462383807773
# Running model: SVR_rbf_C10 with imputers mean, knn10
# Model completed in 1.56 seconds. RMSE: 19.723914991262646
# Running model: Linear with imputers median, mean
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: Polynomial2 with imputers median, mean
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: ElasticNet0.5 with imputers median, mean
# Model completed in 0.02 seconds. RMSE: 20.226812731138967
# Running model: ElasticNet1 with imputers median, mean
# Model completed in 0.02 seconds. RMSE: 20.309785690671372
# Running model: KNN5 with imputers median, mean
# Model completed in 0.03 seconds. RMSE: 20.857356360757656
# Running model: KNN10 with imputers median, mean
# Model completed in 0.03 seconds. RMSE: 19.940336783712194
# Running model: FullRandForest with imputers median, mean
# Model completed in 6.20 seconds. RMSE: 19.587716058161597
# Running model: SmallRandForest with imputers median, mean
# Model completed in 1.43 seconds. RMSE: 19.435742680715702
# Running model: SVR_poly_C1 with imputers median, mean
# Model completed in 0.82 seconds. RMSE: 21.074126132337486
# Running model: SVR_poly_C10 with imputers median, mean
# Model completed in 1.27 seconds. RMSE: 20.658470944095093
# Running model: SVR_rbf_C1 with imputers median, mean
# Model completed in 1.37 seconds. RMSE: 20.417621140693168
# Running model: SVR_rbf_C10 with imputers median, mean
# Model completed in 1.60 seconds. RMSE: 19.726351679667392
# Running model: Linear with imputers median, median
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: Polynomial2 with imputers median, median
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: ElasticNet0.5 with imputers median, median
# Model completed in 0.02 seconds. RMSE: 20.226812731138967
# Running model: ElasticNet1 with imputers median, median
# Model completed in 0.02 seconds. RMSE: 20.309785690671372
# Running model: KNN5 with imputers median, median
# Model completed in 0.03 seconds. RMSE: 20.857356360757656
# Running model: KNN10 with imputers median, median
# Model completed in 0.03 seconds. RMSE: 19.940336783712194
# Running model: FullRandForest with imputers median, median
# Model completed in 6.20 seconds. RMSE: 19.473526564783796
# Running model: SmallRandForest with imputers median, median
# Model completed in 1.42 seconds. RMSE: 19.465655990022217
# Running model: SVR_poly_C1 with imputers median, median
# Model completed in 0.81 seconds. RMSE: 21.074126132337486
# Running model: SVR_poly_C10 with imputers median, median
# Model completed in 1.36 seconds. RMSE: 20.658470944095093
# Running model: SVR_rbf_C1 with imputers median, median
# Model completed in 1.37 seconds. RMSE: 20.417621140693168
# Running model: SVR_rbf_C10 with imputers median, median
# Model completed in 1.62 seconds. RMSE: 19.726351679667392
# Running model: Linear with imputers median, mode
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: Polynomial2 with imputers median, mode
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: ElasticNet0.5 with imputers median, mode
# Model completed in 0.03 seconds. RMSE: 20.226812731138967
# Running model: ElasticNet1 with imputers median, mode
# Model completed in 0.03 seconds. RMSE: 20.309785690671372
# Running model: KNN5 with imputers median, mode
# Model completed in 0.03 seconds. RMSE: 20.857356360757656
# Running model: KNN10 with imputers median, mode
# Model completed in 0.04 seconds. RMSE: 19.940336783712194
# Running model: FullRandForest with imputers median, mode
# Model completed in 6.22 seconds. RMSE: 19.51503524750887
# Running model: SmallRandForest with imputers median, mode
# Model completed in 1.43 seconds. RMSE: 19.39532169734776
# Running model: SVR_poly_C1 with imputers median, mode
# Model completed in 0.81 seconds. RMSE: 21.074126132337486
# Running model: SVR_poly_C10 with imputers median, mode
# Model completed in 1.28 seconds. RMSE: 20.658470944095093
# Running model: SVR_rbf_C1 with imputers median, mode
# Model completed in 1.38 seconds. RMSE: 20.417621140693168
# Running model: SVR_rbf_C10 with imputers median, mode
# Model completed in 1.57 seconds. RMSE: 19.726351679667392
# Running model: Linear with imputers median, knn5
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: Polynomial2 with imputers median, knn5
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: ElasticNet0.5 with imputers median, knn5
# Model completed in 0.02 seconds. RMSE: 20.226812731138967
# Running model: ElasticNet1 with imputers median, knn5
# Model completed in 0.02 seconds. RMSE: 20.309785690671372
# Running model: KNN5 with imputers median, knn5
# Model completed in 0.03 seconds. RMSE: 20.857356360757656
# Running model: KNN10 with imputers median, knn5
# Model completed in 0.03 seconds. RMSE: 19.940336783712194
# Running model: FullRandForest with imputers median, knn5
# Model completed in 6.16 seconds. RMSE: 19.652850844421174
# Running model: SmallRandForest with imputers median, knn5
# Model completed in 1.42 seconds. RMSE: 19.34302671755187
# Running model: SVR_poly_C1 with imputers median, knn5
# Model completed in 0.81 seconds. RMSE: 21.074126132337486
# Running model: SVR_poly_C10 with imputers median, knn5
# Model completed in 1.27 seconds. RMSE: 20.658470944095093
# Running model: SVR_rbf_C1 with imputers median, knn5
# Model completed in 1.36 seconds. RMSE: 20.417621140693168
# Running model: SVR_rbf_C10 with imputers median, knn5
# Model completed in 1.58 seconds. RMSE: 19.726351679667392
# Running model: Linear with imputers median, knn10
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: Polynomial2 with imputers median, knn10
# Model completed in 0.02 seconds. RMSE: 20.293071325952738
# Running model: ElasticNet0.5 with imputers median, knn10
# Model completed in 0.02 seconds. RMSE: 20.226812731138967
# Running model: ElasticNet1 with imputers median, knn10
# Model completed in 0.02 seconds. RMSE: 20.309785690671372
# Running model: KNN5 with imputers median, knn10
# Model completed in 0.03 seconds. RMSE: 20.857356360757656
# Running model: KNN10 with imputers median, knn10
# Model completed in 0.03 seconds. RMSE: 19.940336783712194
# Running model: FullRandForest with imputers median, knn10
# Model completed in 6.21 seconds. RMSE: 19.631070831192613
# Running model: SmallRandForest with imputers median, knn10
# Model completed in 1.43 seconds. RMSE: 19.21772065244228
# Running model: SVR_poly_C1 with imputers median, knn10
# Model completed in 0.81 seconds. RMSE: 21.074126132337486
# Running model: SVR_poly_C10 with imputers median, knn10
# Model completed in 1.27 seconds. RMSE: 20.658470944095093
# Running model: SVR_rbf_C1 with imputers median, knn10
# Model completed in 1.36 seconds. RMSE: 20.417621140693168
# Running model: SVR_rbf_C10 with imputers median, knn10
# Model completed in 1.58 seconds. RMSE: 19.726351679667392
# Running model: Linear with imputers mode, mean
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: Polynomial2 with imputers mode, mean
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: ElasticNet0.5 with imputers mode, mean
# Model completed in 0.03 seconds. RMSE: 20.227286350490306
# Running model: ElasticNet1 with imputers mode, mean
# Model completed in 0.03 seconds. RMSE: 20.313382007215562
# Running model: KNN5 with imputers mode, mean
# Model completed in 0.04 seconds. RMSE: 21.060538011160453
# Running model: KNN10 with imputers mode, mean
# Model completed in 0.04 seconds. RMSE: 19.981022853101013
# Running model: FullRandForest with imputers mode, mean
# Model completed in 6.18 seconds. RMSE: 19.56799112948151
# Running model: SmallRandForest with imputers mode, mean
# Model completed in 1.44 seconds. RMSE: 19.129287485749096
# Running model: SVR_poly_C1 with imputers mode, mean
# Model completed in 0.79 seconds. RMSE: 21.031664165391952
# Running model: SVR_poly_C10 with imputers mode, mean
# Model completed in 1.24 seconds. RMSE: 20.604589571717604
# Running model: SVR_rbf_C1 with imputers mode, mean
# Model completed in 1.36 seconds. RMSE: 20.39904872130263
# Running model: SVR_rbf_C10 with imputers mode, mean
# Model completed in 1.62 seconds. RMSE: 19.71489959504542
# Running model: Linear with imputers mode, median
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: Polynomial2 with imputers mode, median
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: ElasticNet0.5 with imputers mode, median
# Model completed in 0.03 seconds. RMSE: 20.227286350490306
# Running model: ElasticNet1 with imputers mode, median
# Model completed in 0.03 seconds. RMSE: 20.313382007215562
# Running model: KNN5 with imputers mode, median
# Model completed in 0.04 seconds. RMSE: 21.060538011160453
# Running model: KNN10 with imputers mode, median
# Model completed in 0.04 seconds. RMSE: 19.981022853101013
# Running model: FullRandForest with imputers mode, median
# Model completed in 6.16 seconds. RMSE: 19.59779557163988
# Running model: SmallRandForest with imputers mode, median
# Model completed in 1.47 seconds. RMSE: 19.251379243157892
# Running model: SVR_poly_C1 with imputers mode, median
# Model completed in 0.82 seconds. RMSE: 21.031664165391952
# Running model: SVR_poly_C10 with imputers mode, median
# Model completed in 1.29 seconds. RMSE: 20.604589571717604
# Running model: SVR_rbf_C1 with imputers mode, median
# Model completed in 1.36 seconds. RMSE: 20.39904872130263
# Running model: SVR_rbf_C10 with imputers mode, median
# Model completed in 1.60 seconds. RMSE: 19.71489959504542
# Running model: Linear with imputers mode, mode
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: Polynomial2 with imputers mode, mode
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: ElasticNet0.5 with imputers mode, mode
# Model completed in 0.03 seconds. RMSE: 20.227286350490306
# Running model: ElasticNet1 with imputers mode, mode
# Model completed in 0.03 seconds. RMSE: 20.313382007215562
# Running model: KNN5 with imputers mode, mode
# Model completed in 0.03 seconds. RMSE: 21.060538011160453
# Running model: KNN10 with imputers mode, mode
# Model completed in 0.04 seconds. RMSE: 19.981022853101013
# Running model: FullRandForest with imputers mode, mode
# Model completed in 6.18 seconds. RMSE: 19.486035766913794
# Running model: SmallRandForest with imputers mode, mode
# Model completed in 1.43 seconds. RMSE: 19.293794954945582
# Running model: SVR_poly_C1 with imputers mode, mode
# Model completed in 0.80 seconds. RMSE: 21.031664165391952
# Running model: SVR_poly_C10 with imputers mode, mode
# Model completed in 1.27 seconds. RMSE: 20.604589571717604
# Running model: SVR_rbf_C1 with imputers mode, mode
# Model completed in 1.38 seconds. RMSE: 20.39904872130263
# Running model: SVR_rbf_C10 with imputers mode, mode
# Model completed in 1.60 seconds. RMSE: 19.71489959504542
# Running model: Linear with imputers mode, knn5
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: Polynomial2 with imputers mode, knn5
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: ElasticNet0.5 with imputers mode, knn5
# Model completed in 0.03 seconds. RMSE: 20.227286350490306
# Running model: ElasticNet1 with imputers mode, knn5
# Model completed in 0.03 seconds. RMSE: 20.313382007215562
# Running model: KNN5 with imputers mode, knn5
# Model completed in 0.03 seconds. RMSE: 21.060538011160453
# Running model: KNN10 with imputers mode, knn5
# Model completed in 0.04 seconds. RMSE: 19.981022853101013
# Running model: FullRandForest with imputers mode, knn5
# Model completed in 6.12 seconds. RMSE: 19.408926323266627
# Running model: SmallRandForest with imputers mode, knn5
# Model completed in 1.43 seconds. RMSE: 19.26976519205018
# Running model: SVR_poly_C1 with imputers mode, knn5
# Model completed in 0.81 seconds. RMSE: 21.031664165391952
# Running model: SVR_poly_C10 with imputers mode, knn5
# Model completed in 1.26 seconds. RMSE: 20.604589571717604
# Running model: SVR_rbf_C1 with imputers mode, knn5
# Model completed in 1.37 seconds. RMSE: 20.39904872130263
# Running model: SVR_rbf_C10 with imputers mode, knn5
# Model completed in 1.57 seconds. RMSE: 19.71489959504542
# Running model: Linear with imputers mode, knn10
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: Polynomial2 with imputers mode, knn10
# Model completed in 0.03 seconds. RMSE: 20.282118677992187
# Running model: ElasticNet0.5 with imputers mode, knn10
# Model completed in 0.03 seconds. RMSE: 20.227286350490306
# Running model: ElasticNet1 with imputers mode, knn10
# Model completed in 0.03 seconds. RMSE: 20.313382007215562
# Running model: KNN5 with imputers mode, knn10
# Model completed in 0.04 seconds. RMSE: 21.060538011160453
# Running model: KNN10 with imputers mode, knn10
# Model completed in 0.04 seconds. RMSE: 19.981022853101013
# Running model: FullRandForest with imputers mode, knn10
# Model completed in 6.16 seconds. RMSE: 19.587690814283437
# Running model: SmallRandForest with imputers mode, knn10
# Model completed in 1.42 seconds. RMSE: 19.093986655244358
# Running model: SVR_poly_C1 with imputers mode, knn10
# Model completed in 0.81 seconds. RMSE: 21.031664165391952
# Running model: SVR_poly_C10 with imputers mode, knn10
# Model completed in 1.24 seconds. RMSE: 20.604589571717604
# Running model: SVR_rbf_C1 with imputers mode, knn10
# Model completed in 1.38 seconds. RMSE: 20.39904872130263
# Running model: SVR_rbf_C10 with imputers mode, knn10
# Model completed in 1.56 seconds. RMSE: 19.71489959504542
# Running model: Linear with imputers knn5, mean
# Model completed in 2.63 seconds. RMSE: 20.28726431905573
# Running model: Polynomial2 with imputers knn5, mean
# Model completed in 2.82 seconds. RMSE: 20.28726431905573
# Running model: ElasticNet0.5 with imputers knn5, mean
# Model completed in 2.66 seconds. RMSE: 20.227804476695503
# Running model: ElasticNet1 with imputers knn5, mean
# Model completed in 2.79 seconds. RMSE: 20.310339790878075
# Running model: KNN5 with imputers knn5, mean
# Model completed in 2.69 seconds. RMSE: 20.68997357340761
# Running model: KNN10 with imputers knn5, mean
# Model completed in 2.67 seconds. RMSE: 20.134177336672575
# Running model: FullRandForest with imputers knn5, mean
# Model completed in 10.12 seconds. RMSE: 19.596976784556265
# Running model: SmallRandForest with imputers knn5, mean
# Model completed in 4.47 seconds. RMSE: 19.27042330911164
# Running model: SVR_poly_C1 with imputers knn5, mean
# Model completed in 3.37 seconds. RMSE: 21.031396273807083
# Running model: SVR_poly_C10 with imputers knn5, mean
# Model completed in 3.97 seconds. RMSE: 20.498901087790028
# Running model: SVR_rbf_C1 with imputers knn5, mean
# Model completed in 3.92 seconds. RMSE: 20.386994067860368
# Running model: SVR_rbf_C10 with imputers knn5, mean
# Model completed in 4.23 seconds. RMSE: 19.723797574075014
# Running model: Linear with imputers knn5, median
# Model completed in 2.67 seconds. RMSE: 20.28726431905573
# Running model: Polynomial2 with imputers knn5, median
# Model completed in 2.71 seconds. RMSE: 20.28726431905573
# Running model: ElasticNet0.5 with imputers knn5, median
# Model completed in 2.65 seconds. RMSE: 20.227804476695503
# Running model: ElasticNet1 with imputers knn5, median
# Model completed in 2.61 seconds. RMSE: 20.310339790878075
# Running model: KNN5 with imputers knn5, median
# Model completed in 2.63 seconds. RMSE: 20.68997357340761
# Running model: KNN10 with imputers knn5, median
# Model completed in 2.60 seconds. RMSE: 20.134177336672575
# Running model: FullRandForest with imputers knn5, median
# Model completed in 9.87 seconds. RMSE: 19.453578599077307
# Running model: SmallRandForest with imputers knn5, median
# Model completed in 4.41 seconds. RMSE: 19.283691290765614
# Running model: SVR_poly_C1 with imputers knn5, median
# Model completed in 3.46 seconds. RMSE: 21.031396273807083
# Running model: SVR_poly_C10 with imputers knn5, median
# Model completed in 3.97 seconds. RMSE: 20.498901087790028
# Running model: SVR_rbf_C1 with imputers knn5, median
# Model completed in 4.01 seconds. RMSE: 20.386994067860368
# Running model: SVR_rbf_C10 with imputers knn5, median
# Model completed in 4.24 seconds. RMSE: 19.723797574075014
# Running model: Linear with imputers knn5, mode
# Model completed in 2.61 seconds. RMSE: 20.28726431905573
# Running model: Polynomial2 with imputers knn5, mode
# Model completed in 2.66 seconds. RMSE: 20.28726431905573
# Running model: ElasticNet0.5 with imputers knn5, mode
# Model completed in 2.70 seconds. RMSE: 20.227804476695503
# Running model: ElasticNet1 with imputers knn5, mode
# Model completed in 2.61 seconds. RMSE: 20.310339790878075
# Running model: KNN5 with imputers knn5, mode
# Model completed in 2.60 seconds. RMSE: 20.68997357340761
# Running model: KNN10 with imputers knn5, mode
# Model completed in 2.63 seconds. RMSE: 20.134177336672575
# Running model: FullRandForest with imputers knn5, mode
# Model completed in 10.01 seconds. RMSE: 19.471349435406502
# Running model: SmallRandForest with imputers knn5, mode
# Model completed in 4.40 seconds. RMSE: 19.407608517879044
# Running model: SVR_poly_C1 with imputers knn5, mode
# Model completed in 3.34 seconds. RMSE: 21.031396273807083
# Running model: SVR_poly_C10 with imputers knn5, mode
# Model completed in 3.94 seconds. RMSE: 20.498901087790028
# Running model: SVR_rbf_C1 with imputers knn5, mode
# Model completed in 3.96 seconds. RMSE: 20.386994067860368
# Running model: SVR_rbf_C10 with imputers knn5, mode
# Model completed in 4.10 seconds. RMSE: 19.723797574075014
# Running model: Linear with imputers knn5, knn5
# Model completed in 2.56 seconds. RMSE: 20.28726431905573
# Running model: Polynomial2 with imputers knn5, knn5
# Model completed in 2.59 seconds. RMSE: 20.28726431905573
# Running model: ElasticNet0.5 with imputers knn5, knn5
# Model completed in 2.58 seconds. RMSE: 20.227804476695503
# Running model: ElasticNet1 with imputers knn5, knn5
# Model completed in 2.62 seconds. RMSE: 20.310339790878075
# Running model: KNN5 with imputers knn5, knn5
# Model completed in 2.63 seconds. RMSE: 20.68997357340761
# Running model: KNN10 with imputers knn5, knn5
# Model completed in 2.60 seconds. RMSE: 20.134177336672575
# Running model: FullRandForest with imputers knn5, knn5
# Model completed in 9.88 seconds. RMSE: 19.56709830870458
# Running model: SmallRandForest with imputers knn5, knn5
# Model completed in 4.38 seconds. RMSE: 19.158697078932363
# Running model: SVR_poly_C1 with imputers knn5, knn5
# Model completed in 3.33 seconds. RMSE: 21.031396273807083
# Running model: SVR_poly_C10 with imputers knn5, knn5
# Model completed in 3.91 seconds. RMSE: 20.498901087790028
# Running model: SVR_rbf_C1 with imputers knn5, knn5
# Model completed in 3.91 seconds. RMSE: 20.386994067860368
# Running model: SVR_rbf_C10 with imputers knn5, knn5
# Model completed in 4.10 seconds. RMSE: 19.723797574075014
# Running model: Linear with imputers knn5, knn10
# Model completed in 2.60 seconds. RMSE: 20.28726431905573
# Running model: Polynomial2 with imputers knn5, knn10
# Model completed in 2.56 seconds. RMSE: 20.28726431905573
# Running model: ElasticNet0.5 with imputers knn5, knn10
# Model completed in 2.58 seconds. RMSE: 20.227804476695503
# Running model: ElasticNet1 with imputers knn5, knn10
# Model completed in 2.58 seconds. RMSE: 20.310339790878075
# Running model: KNN5 with imputers knn5, knn10
# Model completed in 2.61 seconds. RMSE: 20.68997357340761
# Running model: KNN10 with imputers knn5, knn10
# Model completed in 2.60 seconds. RMSE: 20.134177336672575
# Running model: FullRandForest with imputers knn5, knn10
# Model completed in 9.87 seconds. RMSE: 19.507012977491208
# Running model: SmallRandForest with imputers knn5, knn10
# Model completed in 4.35 seconds. RMSE: 19.266065283031608
# Running model: SVR_poly_C1 with imputers knn5, knn10
# Model completed in 3.36 seconds. RMSE: 21.031396273807083
# Running model: SVR_poly_C10 with imputers knn5, knn10
# Model completed in 4.06 seconds. RMSE: 20.498901087790028
# Running model: SVR_rbf_C1 with imputers knn5, knn10
# Model completed in 3.93 seconds. RMSE: 20.386994067860368
# Running model: SVR_rbf_C10 with imputers knn5, knn10
# Model completed in 4.12 seconds. RMSE: 19.723797574075014
# Running model: Linear with imputers knn10, mean
# Model completed in 2.60 seconds. RMSE: 20.272400243839144
# Running model: Polynomial2 with imputers knn10, mean
# Model completed in 2.56 seconds. RMSE: 20.272400243839144
# Running model: ElasticNet0.5 with imputers knn10, mean
# Model completed in 2.61 seconds. RMSE: 20.213045103409783
# Running model: ElasticNet1 with imputers knn10, mean
# Model completed in 2.60 seconds. RMSE: 20.301036929950715
# Running model: KNN5 with imputers knn10, mean
# Model completed in 2.59 seconds. RMSE: 20.96061112250116
# Running model: KNN10 with imputers knn10, mean
# Model completed in 2.62 seconds. RMSE: 19.887187005350196
# Running model: FullRandForest with imputers knn10, mean
# Model completed in 10.06 seconds. RMSE: 19.47003957389547
# Running model: SmallRandForest with imputers knn10, mean
# Model completed in 4.39 seconds. RMSE: 19.12984077900287
# Running model: SVR_poly_C1 with imputers knn10, mean
# Model completed in 3.46 seconds. RMSE: 21.016972376479867
# Running model: SVR_poly_C10 with imputers knn10, mean
# Model completed in 4.01 seconds. RMSE: 20.464661451842293
# Running model: SVR_rbf_C1 with imputers knn10, mean
# Model completed in 4.07 seconds. RMSE: 20.3658003402936
# Running model: SVR_rbf_C10 with imputers knn10, mean
# Model completed in 4.28 seconds. RMSE: 19.658681489690235
# Running model: Linear with imputers knn10, median
# Model completed in 2.72 seconds. RMSE: 20.272400243839144
# Running model: Polynomial2 with imputers knn10, median
# Model completed in 2.76 seconds. RMSE: 20.272400243839144
# Running model: ElasticNet0.5 with imputers knn10, median
# Model completed in 2.69 seconds. RMSE: 20.213045103409783
# Running model: ElasticNet1 with imputers knn10, median
# Model completed in 2.65 seconds. RMSE: 20.301036929950715
# Running model: KNN5 with imputers knn10, median
# Model completed in 2.69 seconds. RMSE: 20.96061112250116
# Running model: KNN10 with imputers knn10, median
# Model completed in 2.74 seconds. RMSE: 19.887187005350196
# Running model: FullRandForest with imputers knn10, median
# Model completed in 10.19 seconds. RMSE: 19.57133340711539
# Running model: SmallRandForest with imputers knn10, median
# Model completed in 4.45 seconds. RMSE: 19.341892677219146
# Running model: SVR_poly_C1 with imputers knn10, median
# Model completed in 3.45 seconds. RMSE: 21.016972376479867
# Running model: SVR_poly_C10 with imputers knn10, median
# Model completed in 3.91 seconds. RMSE: 20.464661451842293
# Running model: SVR_rbf_C1 with imputers knn10, median
# Model completed in 3.98 seconds. RMSE: 20.3658003402936
# Running model: SVR_rbf_C10 with imputers knn10, median
# Model completed in 4.28 seconds. RMSE: 19.658681489690235
# Running model: Linear with imputers knn10, mode
# Model completed in 2.66 seconds. RMSE: 20.272400243839144
# Running model: Polynomial2 with imputers knn10, mode
# Model completed in 2.66 seconds. RMSE: 20.272400243839144
# Running model: ElasticNet0.5 with imputers knn10, mode
# Model completed in 2.66 seconds. RMSE: 20.213045103409783
# Running model: ElasticNet1 with imputers knn10, mode
# Model completed in 2.67 seconds. RMSE: 20.301036929950715
# Running model: KNN5 with imputers knn10, mode
# Model completed in 2.67 seconds. RMSE: 20.96061112250116
# Running model: KNN10 with imputers knn10, mode
# Model completed in 2.68 seconds. RMSE: 19.887187005350196
# Running model: FullRandForest with imputers knn10, mode
# Model completed in 10.10 seconds. RMSE: 19.46732069641389
# Running model: SmallRandForest with imputers knn10, mode
# Model completed in 4.46 seconds. RMSE: 19.232978707582944
# Running model: SVR_poly_C1 with imputers knn10, mode
# Model completed in 3.44 seconds. RMSE: 21.016972376479867
# Running model: SVR_poly_C10 with imputers knn10, mode
# Model completed in 3.90 seconds. RMSE: 20.464661451842293
# Running model: SVR_rbf_C1 with imputers knn10, mode
# Model completed in 3.98 seconds. RMSE: 20.3658003402936
# Running model: SVR_rbf_C10 with imputers knn10, mode
# Model completed in 4.20 seconds. RMSE: 19.658681489690235
# Running model: Linear with imputers knn10, knn5
# Model completed in 2.70 seconds. RMSE: 20.272400243839144
# Running model: Polynomial2 with imputers knn10, knn5
# Model completed in 2.64 seconds. RMSE: 20.272400243839144
# Running model: ElasticNet0.5 with imputers knn10, knn5
# Model completed in 2.65 seconds. RMSE: 20.213045103409783
# Running model: ElasticNet1 with imputers knn10, knn5
# Model completed in 2.65 seconds. RMSE: 20.301036929950715
# Running model: KNN5 with imputers knn10, knn5
# Model completed in 2.71 seconds. RMSE: 20.96061112250116
# Running model: KNN10 with imputers knn10, knn5
# Model completed in 2.71 seconds. RMSE: 19.887187005350196
# Running model: FullRandForest with imputers knn10, knn5
# Model completed in 10.12 seconds. RMSE: 19.473308343463007
# Running model: SmallRandForest with imputers knn10, knn5
# Model completed in 4.46 seconds. RMSE: 19.441836809966535
# Running model: SVR_poly_C1 with imputers knn10, knn5
# Model completed in 3.43 seconds. RMSE: 21.016972376479867
# Running model: SVR_poly_C10 with imputers knn10, knn5
# Model completed in 3.90 seconds. RMSE: 20.464661451842293
# Running model: SVR_rbf_C1 with imputers knn10, knn5
# Model completed in 3.97 seconds. RMSE: 20.3658003402936
# Running model: SVR_rbf_C10 with imputers knn10, knn5
# Model completed in 4.32 seconds. RMSE: 19.658681489690235
# Running model: Linear with imputers knn10, knn10
# Model completed in 2.65 seconds. RMSE: 20.272400243839144
# Running model: Polynomial2 with imputers knn10, knn10
# Model completed in 2.76 seconds. RMSE: 20.272400243839144
# Running model: ElasticNet0.5 with imputers knn10, knn10
# Model completed in 2.74 seconds. RMSE: 20.213045103409783
# Running model: ElasticNet1 with imputers knn10, knn10
# Model completed in 2.67 seconds. RMSE: 20.301036929950715
# Running model: KNN5 with imputers knn10, knn10
# Model completed in 2.75 seconds. RMSE: 20.96061112250116
# Running model: KNN10 with imputers knn10, knn10
# Model completed in 2.72 seconds. RMSE: 19.887187005350196
# Running model: FullRandForest with imputers knn10, knn10
# Model completed in 10.22 seconds. RMSE: 19.333523899634773
# Running model: SmallRandForest with imputers knn10, knn10
# Model completed in 4.47 seconds. RMSE: 18.964169212205164
# Running model: SVR_poly_C1 with imputers knn10, knn10
# Model completed in 3.45 seconds. RMSE: 21.016972376479867
# Running model: SVR_poly_C10 with imputers knn10, knn10
# Model completed in 3.95 seconds. RMSE: 20.464661451842293
# Running model: SVR_rbf_C1 with imputers knn10, knn10
# Model completed in 3.97 seconds. RMSE: 20.3658003402936
# Running model: SVR_rbf_C10 with imputers knn10, knn10
# Model completed in 4.20 seconds. RMSE: 19.658681489690235
# Test RMSE: 18.22284376835199

# %% [markdown]
# Top ten models

# %%
print("Top 10 Best Models and their RMSEs:")
for i, result in enumerate(results[:10]):
    print(f"Rank {i+1}: Parameters - {result['params']}, RMSE - {result['rmse']:.2f}")

print("Test RMSE of the Best Model:", test_rmse)
# Out:
# Top 10 Best Models and their RMSEs:
# Rank 1: Parameters - {'cont_imputer': 'mean', 'cat_imputer': 'knn10', 'model': 'SmallRandForest'}, RMSE - 18.85
# Rank 2: Parameters - {'cont_imputer': 'mean', 'cat_imputer': 'median', 'model': 'SmallRandForest'}, RMSE - 18.92
# Rank 3: Parameters - {'cont_imputer': 'mean', 'cat_imputer': 'mode', 'model': 'SmallRandForest'}, RMSE - 18.95
# Rank 4: Parameters - {'cont_imputer': 'knn10', 'cat_imputer': 'knn10', 'model': 'SmallRandForest'}, RMSE - 18.96
# Rank 5: Parameters - {'cont_imputer': 'mean', 'cat_imputer': 'mean', 'model': 'SmallRandForest'}, RMSE - 18.98
# Rank 6: Parameters - {'cont_imputer': 'mean', 'cat_imputer': 'knn5', 'model': 'SmallRandForest'}, RMSE - 19.00
# Rank 7: Parameters - {'cont_imputer': 'mean', 'cat_imputer': 'mean', 'model': 'FullRandForest'}, RMSE - 19.06
# Rank 8: Parameters - {'cont_imputer': 'mode', 'cat_imputer': 'knn10', 'model': 'SmallRandForest'}, RMSE - 19.09
# Rank 9: Parameters - {'cont_imputer': 'mean', 'cat_imputer': 'knn10', 'model': 'FullRandForest'}, RMSE - 19.12
# Rank 10: Parameters - {'cont_imputer': 'mode', 'cat_imputer': 'mean', 'model': 'SmallRandForest'}, RMSE - 19.13
# Test RMSE of the Best Model: 18.22284376835199

# %% [markdown]
# Best pipeline

# %%
best_pipeline
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['alder', 'utdanning', 'sykehusdød', 'blodtrykk', 'hvite_blodlegemer',
#        'hjertefrekvens', 'respirasjonsfrekvens', 'kroppstemperatur',
#        'lungefunksjon', 'serumalbumin', 'bilirubin', 'kreatinin', 'natrium',
#        'blod_ph', 'g...
#        'adl_stedfortreder', 'fysiologisk_score', 'apache_fysiologisk_score',
#        'overlevelsesestimat_2mnd', 'overlevelsesestimat_6mnd', 'diabetes',
#        'demens', 'lege_overlevelsesestimat_2mnd',
#        'lege_overlevelsesestimat_6mnd', 'dnr_dag'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('impute',
#                                                                    KNNImputer(n_neighbors=10))]),
#                                                   Index([], dtype='object'))])),
#                 ('model',
#                  RandomForestRegressor(max_depth=10, n_estimators=50))])
